# %%
import sys
sys.path.append("../../../")

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
import os

# %%
import numpy as np
from hamiltonian import utils

# %%
path = []
for dirname, _, filenames in os.walk('../kaggle/input'):
    print(dirname)
    for filename in filenames:
        if (filename[-3:] == 'png'):
            path.append(os.path.join(dirname, filename))

# %%
fullpath = "../../../kaggle/input/covid19-radiography-database/COVID-19_Radiography_Dataset"

os.listdir(fullpath)
# Out:
# ['README.md.txt',
#  'COVID',
#  'Lung_Opacity',
#  'Normal.metadata.xlsx',
#  'Lung_Opacity.metadata.xlsx',
#  'COVID.metadata.xlsx',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia.metadata.xlsx']

# %%
list_files=[]
for dir in os.listdir(fullpath):
  directory = os.path.join(fullpath,dir)
  
  if os.path.isdir(directory):
    for img in os.listdir(directory):
      list_files.append([os.path.join(dir,img),dir])
df = pd.DataFrame(list_files, columns=['id','label'])
df.describe()
list_files = []
for dir in os.listdir(fullpath):
  directory = os.path.join(fullpath,dir)

import seaborn as sns
sns.countplot(df.label)
plt.show()
# Out:
# /home/proyecto/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import mxnet
from mxnet import image, nd
dim = 150

# %%
cant_img = 600#cantidad de imagenes a procesar

count = 0
'''
for img_path in glob.glob(DATASET_DIR + "/Normal/*"):
    count += 1
    normal_images.append(image.load_img(str(img_path), target_size = (150,150,3)))
   
    if count > 300:
        break
   '''    
covid_images = []
count1 = 0

for img_path in glob.glob(fullpath + "/COVID/*"):
    count1 += 1
    imagen = image.imread(img_path)
    recorte = mxnet.img.imresize(imagen, dim,dim)
    covid_images.append(recorte)
    if count1 > cant_img:
        break
'''Lung_opcaity = []
count2 = 0

for img_path in glob.glob(fullpath + "/Lung_Opacity/*"):
    count2 += 1
    imagen = image.imread(img_path)
    recorte = mxnet.img.imresize(imagen, dim,dim)
    Lung_opcaity.append(recorte)
    if count2 > cant_img:
        break'''

normal_images = []
count2 = 0

for img_path in glob.glob(fullpath + "/Normal/*"):
    count2 += 1
    imagen = image.imread(img_path)
    recorte = mxnet.img.imresize(imagen, dim,dim)
    normal_images.append(recorte)
    if count2 > cant_img:
        break
        
Viral_pneumonia = []
count3 = 0

for img_path in glob.glob(fullpath + "/Viral Pneumonia/*"):
    count3 += 1
    imagen = image.imread(img_path)
    recorte = mxnet.img.imresize(imagen, dim,dim)
    Viral_pneumonia.append(recorte)
    if count3 > cant_img:
        break
        

                
        
total=count1+count2+count3#total imagenes
# Out:
# [12:44:45] /home/proyecto/mxnet/src/storage/storage.cc:199: Using Pooled (Naive) StorageManager for CPU

# %%
y=[]
images_together = []#nd.zeros(shape=((cant_img+1)*3,150,150,3))
'''
for i in normal_images:
    images_together.append(img_to_array(i))
    target.append(0)
'''
#count_global = 0

count1 = 0
for i in covid_images:
    images_together.append(i.asnumpy())#[count_global] = i
    y.append(0)
    count1=count1+1
    #count_global=count_global+1

'''count2 = 0
for i in Lung_opcaity:
    images_together.append(i.asnumpy())#[count_global] = i
    y.append(1)
    count2=count2+1'''
    #count_global=count_global+1
    
count2 = 0
for i in normal_images:
    images_together.append(i.asnumpy())#[count_global] = i
    y.append(1)
    count2=count2+1
    #count_global=count_global+1
    
count3 = 0
for i in Viral_pneumonia:
    images_together.append(i.asnumpy())#[count_global] = i
    y.append(2)
    count3=count3+1
    #count_global=count_global+1

print(len(images_together))
print(len(y))
# Out:
# 1803
# 1803

# %%
images_together[0]
clases = ["Covid","Normal", "Neumonia_viral"]
indices = [5,804,1500]

fig, (ax1,ax2, ax3) = plt.subplots(1,3)

ax1.title.set_text('Covid')
ax1.imshow(images_together[indices[0]])
ax2.title.set_text('Normal')
ax2.imshow(images_together[indices[1]])
ax3.title.set_text('Neumonia_viral')
ax3.imshow(images_together[indices[2]])

for i in range(len(indices)):
    print(y[indices[i]],"Clase: "+clases[i])
# Out:
# 0 Clase: Covid
# 1 Clase: Normal
# 2 Clase: Neumonia_viral

# %%
for i in range(len(images_together)):#normalizacion
    images_together[i] = images_together[i]/255.0

# %%
import mxnet.gluon.probability as mxp
y=np.array(y)
print(y)
# Out:
# [0 0 0 ... 2 2 2]

# %%
import numpy as np
images_together = np.array(images_together)
print("shape of images together: ",images_together.shape)
print("type of images together",type(images_together))
print("shape of y: ",y.shape)
# Out:
# shape of images together:  (1803, 150, 150, 3)
# type of images together <class 'numpy.ndarray'>
# shape of y:  (1803,)

# %%
images_together=images_together.reshape((cant_img+1)*3,3,dim,dim)
#print(images_together.shape)
#images_together=images_together.reshape((cant_img+1)*3,3*150*150)
print(images_together.shape)
images_together = images_together.astype(np.float32)
print(images_together.dtype)
print(y.shape)
print(y.dtype)
# Out:
# (1803, 3, 150, 150)
# float32
# (1803,)
# int64

# %%
from sklearn.model_selection import train_test_split
X_train, x_test, y_train, y_test = train_test_split(images_together, y, test_size=0.2, random_state=42, shuffle = True)

images_together = np.concatenate((X_train, x_test))
y = np.concatenate((y_train, y_test))

# %%
import mxnet as mx
from mxnet import gluon, nd

num_gpus = 1
model_ctx = mxnet.cpu()

num_workers = 8
batch_size = 64 

dataset_train = gluon.data.dataset.ArrayDataset(X_train, y_train)
data_loader_train = gluon.data.DataLoader(dataset_train, batch_size = batch_size, shuffle=True, last_batch='discard',  num_workers=0)

dataset_test = gluon.data.dataset.ArrayDataset(X_train, y_train)
data_loader_test = gluon.data.DataLoader(dataset_test, batch_size = batch_size,  shuffle=True, last_batch='discard', num_workers=0)

# %%
print(data_loader_train)
for X,y in data_loader_train:
    print(X.shape)
    print(y.shape)
    break
# Out:
# <mxnet.gluon.data.dataloader.DataLoader object at 0x7f777d6ad790>
# (64, 3, 150, 150)
# (64,)

# %% [markdown]
# # SGLD - Resnet

# %%
import numpy as np
from hamiltonian import utils

num_examples,channel,w,h=X_train.shape
num_input=channel*w*h
num_outputs=len(np.unique(y_train))

#y_train=utils.one_hot(y_train,num_outputs)
#y_test=utils.one_hot(y_test,num_outputs)

# %%
print(num_examples)
print(num_input)
print(num_outputs)
# Out:
# 1442
# 67500
# 3

# %%
import mxnet as mx
from mxnet import nd, autograd, gluon
model_ctx=mx.cpu()
hyper={'alpha':10.}
#in_units=X_train.shape[2],X_train.shape[3]
in_units=(dim,dim)
out_units=len(np.unique(y_train))
print(in_units, out_units)
n_layers=18
pre_trained=False
# Out:
# (150, 150) 3

# %%
import mxnet as mx
from hamiltonian.inference.sgld import sgld
from hamiltonian.models.softmax import resnet_softmax

model=resnet_softmax(hyper,in_units,out_units,n_layers,pre_trained,ctx=model_ctx)
inference=sgld(model,model.par,step_size=0.01,ctx=model_ctx)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import glob

train_sgld=True
num_epochs=10

if train_sgld:
    loss,posterior_samples=inference.sample(epochs=num_epochs,batch_size=batch_size,
                                data_loader=data_loader_train,
                                verbose=True,chain_name='chain_nonhierarchical')

    plt.rcParams['figure.dpi'] = 360
    sns.set_style("whitegrid")
    fig=plt.figure(figsize=[5,5])
    plt.plot(loss[0],color='blue',lw=3)
    plt.plot(loss[1],color='red',lw=3)
    plt.xlabel('Epoch', size=18)
    plt.ylabel('Loss', size=18)
    plt.title('SGLD Resnet COVID', size=18)
    plt.xticks(size=14)
    plt.yticks(size=14)
    plt.savefig('sgld_Resnet.pdf', bbox_inches='tight')
else:
    chain1=glob.glob("chain_nonhierarchical_0_1_sgld*.params")
    chain2=glob.glob("chain_nonhierarchical_0_sgld*.params")
    posterior_samples=[chain1,chain2]
# Out:
#  10%|████▎                                      | 1/10 [03:58<35:47, 238.58s/it]
# loss: 4.3280
#  20%|████████▌                                  | 2/10 [08:57<36:34, 274.33s/it]
# loss: 4.5149
#  30%|████████████▉                              | 3/10 [13:41<32:30, 278.60s/it]
# loss: 4.8592
#  40%|█████████████████▏                         | 4/10 [18:48<28:59, 289.92s/it]
# loss: 5.2002
#  50%|█████████████████████▌                     | 5/10 [24:05<24:57, 299.45s/it]
# loss: 5.6387
#  60%|█████████████████████████▊                 | 6/10 [28:52<19:41, 295.34s/it]
# loss: 6.2414
#  70%|██████████████████████████████             | 7/10 [34:08<15:06, 302.19s/it]
# loss: 6.6937
#  80%|██████████████████████████████████▍        | 8/10 [39:01<09:58, 299.17s/it]
# loss: 7.1160
#  90%|██████████████████████████████████████▋    | 9/10 [44:48<05:14, 314.16s/it]
# loss: 7.6184
# 100%|██████████████████████████████████████████| 10/10 [49:57<00:00, 299.77s/it]
# loss: 8.3240
#  10%|████▎                                      | 1/10 [05:04<45:41, 304.65s/it]
# loss: 4.3330
#  20%|████████▌                                  | 2/10 [09:55<39:30, 296.29s/it]
# loss: 4.4833
#  30%|████████████▉                              | 3/10 [13:56<31:38, 271.28s/it]
# loss: 4.7815
#  40%|█████████████████▏                         | 4/10 [17:46<25:30, 255.10s/it]
# loss: 5.2286
#  50%|█████████████████████▌                     | 5/10 [21:28<20:15, 243.15s/it]
# loss: 5.6072
#  60%|█████████████████████████▊                 | 6/10 [25:05<15:36, 234.04s/it]
# loss: 6.0641
#  70%|██████████████████████████████             | 7/10 [28:29<11:13, 224.37s/it]
# loss: 6.6844
#  80%|██████████████████████████████████▍        | 8/10 [31:59<07:19, 219.60s/it]
# loss: 7.1609
#  90%|██████████████████████████████████████▋    | 9/10 [35:55<03:44, 224.74s/it]
# loss: 7.6849
# 100%|██████████████████████████████████████████| 10/10 [39:48<00:00, 238.80s/it]
# loss: 8.2905

# %%
posterior_samples_flat=[item for sublist in posterior_samples for item in sublist]
posterior_samples_flat
# Out:
# ['chain_nonhierarchical_0_sgld_epoch_0_.params',
#  'chain_nonhierarchical_0_sgld_epoch_1_.params',
#  'chain_nonhierarchical_0_sgld_epoch_2_.params',
#  'chain_nonhierarchical_0_sgld_epoch_3_.params',
#  'chain_nonhierarchical_0_sgld_epoch_4_.params',
#  'chain_nonhierarchical_0_sgld_epoch_5_.params',
#  'chain_nonhierarchical_0_sgld_epoch_6_.params',
#  'chain_nonhierarchical_0_sgld_epoch_7_.params',
#  'chain_nonhierarchical_0_sgld_epoch_8_.params',
#  'chain_nonhierarchical_0_sgld_epoch_9_.params',
#  'chain_nonhierarchical_0_1_sgld_epoch_0_.params',
#  'chain_nonhierarchical_0_1_sgld_epoch_1_.params',
#  'chain_nonhierarchical_0_1_sgld_epoch_2_.params',
#  'chain_nonhierarchical_0_1_sgld_epoch_3_.params',
#  'chain_nonhierarchical_0_1_sgld_epoch_4_.params',
#  'chain_nonhierarchical_0_1_sgld_epoch_5_.params',
#  'chain_nonhierarchical_0_1_sgld_epoch_6_.params',
#  'chain_nonhierarchical_0_1_sgld_epoch_7_.params',
#  'chain_nonhierarchical_0_1_sgld_epoch_8_.params',
#  'chain_nonhierarchical_0_1_sgld_epoch_9_.params']

# %%
total_samples,total_labels,log_like=inference.predict(posterior_samples_flat,5,data_loader=data_loader_test)

# %%
from sklearn.metrics import classification_report

y_hat=np.quantile(total_samples,.5,axis=0)

print(classification_report(np.int32(total_labels),np.int32(y_hat)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.12      0.00      0.00       460
#            1       0.35      1.00      0.51       486
#            2       0.00      0.00      0.00       462
#
#     accuracy                           0.35      1408
#    macro avg       0.16      0.33      0.17      1408
# weighted avg       0.16      0.35      0.18      1408

# %%
total_samples.shape
# Out:
# (20, 1408)

# %%
total_samples[:,1407]
# Out:
# array([1, 1, 2, 2, 0, 1, 1, 1, 1, 1, 0, 1, 1, 1, 2, 2, 0, 0, 1, 1])

# %%
total_labels[1407]
# Out:
# 1

# %%
model.net.collect_params()
# Out:
# {'0.0.gamma': Parameter (shape=(3,), dtype=<class 'numpy.float32'>),
#  '0.0.beta': Parameter (shape=(3,), dtype=<class 'numpy.float32'>),
#  '0.0.running_mean': Parameter (shape=(3,), dtype=<class 'numpy.float32'>),
#  '0.0.running_var': Parameter (shape=(3,), dtype=<class 'numpy.float32'>),
#  '0.1.weight': Parameter (shape=(64, 3, 7, 7), dtype=<class 'numpy.float32'>),
#  '0.2.gamma': Parameter (shape=(64,), dtype=<class 'numpy.float32'>),
#  '0.2.beta': Parameter (shape=(64,), dtype=<class 'numpy.float32'>),
#  '0.2.running_mean': Parameter (shape=(64,), dtype=<class 'numpy.float32'>),
#  '0.2.running_var': Parameter (shape=(64,), dtype=<class 'numpy.float32'>),
#  '0.5.0.bn1.gamma': Parameter (shape=(64,), dtype=<class 'numpy.float32'>),
#  '0.5.0.bn1.beta': Parameter (shape=(64,), dtype=<class 'numpy.float32'>),
#  '0.5.0.bn1.running_mean': Parameter (shape=(64,), dtype=<class 'numpy.float32'>),
#  '0.5.0.bn1.running_var': Parameter (shape=(64,), dtype=<class 'numpy.float32'>),
#  '0.5.0.conv1.weight': Parameter (shape=(64, 64, 3, 3), dtype=<class 'numpy.float32'>),
#  '0.5.0.bn2.gamma': Parameter (shape=(64,), dtype=<class 'numpy.float32'>),
#  '0.5.0.bn2.beta': Parameter (shape=(64,), dtype=<class 'numpy.float32'>),
#  '0.5.0.bn2.running_mean': Parameter (shape=(64,), dtype=<class 'numpy.float32'>),
#  '0.5.0.bn2.running_var': Parameter (shape=(64,), dtype=<class 'numpy.float32'>),
#  '0.5.0.conv2.weight': Parameter (shape=(64, 64, 3, 3), dtype=<class 'numpy.float32'>),
#  '0.5.1.bn1.gamma': Parameter (shape=(64,), dtype=<class 'numpy.float32'>),
#  '0.5.1.bn1.beta': Parameter (shape=(64,), dtype=<class 'numpy.float32'>),
#  '0.5.1.bn1.running_mean': Parameter (shape=(64,), dtype=<class 'numpy.float32'>),
#  '0.5.1.bn1.running_var': Parameter (shape=(64,), dtype=<class 'numpy.float32'>),
#  '0.5.1.conv1.weight': Parameter (shape=(64, 64, 3, 3), dtype=<class 'numpy.float32'>),
#  '0.5.1.bn2.gamma': Parameter (shape=(64,), dtype=<class 'numpy.float32'>),
#  '0.5.1.bn2.beta': Parameter (shape=(64,), dtype=<class 'numpy.float32'>),
#  '0.5.1.bn2.running_mean': Parameter (shape=(64,), dtype=<class 'numpy.float32'>),
#  '0.5.1.bn2.running_var': Parameter (shape=(64,), dtype=<class 'numpy.float32'>),
#  '0.5.1.conv2.weight': Parameter (shape=(64, 64, 3, 3), dtype=<class 'numpy.float32'>),
#  '0.6.0.bn1.gamma': Parameter (shape=(64,), dtype=<class 'numpy.float32'>),
#  '0.6.0.bn1.beta': Parameter (shape=(64,), dtype=<class 'numpy.float32'>),
#  '0.6.0.bn1.running_mean': Parameter (shape=(64,), dtype=<class 'numpy.float32'>),
#  '0.6.0.bn1.running_var': Parameter (shape=(64,), dtype=<class 'numpy.float32'>),
#  '0.6.0.conv1.weight': Parameter (shape=(128, 64, 3, 3), dtype=<class 'numpy.float32'>),
#  '0.6.0.bn2.gamma': Parameter (shape=(128,), dtype=<class 'numpy.float32'>),
#  '0.6.0.bn2.beta': Parameter (shape=(128,), dtype=<class 'numpy.float32'>),
#  '0.6.0.bn2.running_mean': Parameter (shape=(128,), dtype=<class 'numpy.float32'>),
#  '0.6.0.bn2.running_var': Parameter (shape=(128,), dtype=<class 'numpy.float32'>),
#  '0.6.0.conv2.weight': Parameter (shape=(128, 128, 3, 3), dtype=<class 'numpy.float32'>),
#  '0.6.0.downsample.weight': Parameter (shape=(128, 64, 1, 1), dtype=<class 'numpy.float32'>),
#  '0.6.1.bn1.gamma': Parameter (shape=(128,), dtype=<class 'numpy.float32'>),
#  '0.6.1.bn1.beta': Parameter (shape=(128,), dtype=<class 'numpy.float32'>),
#  '0.6.1.bn1.running_mean': Parameter (shape=(128,), dtype=<class 'numpy.float32'>),
#  '0.6.1.bn1.running_var': Parameter (shape=(128,), dtype=<class 'numpy.float32'>),
#  '0.6.1.conv1.weight': Parameter (shape=(128, 128, 3, 3), dtype=<class 'numpy.float32'>),
#  '0.6.1.bn2.gamma': Parameter (shape=(128,), dtype=<class 'numpy.float32'>),
#  '0.6.1.bn2.beta': Parameter (shape=(128,), dtype=<class 'numpy.float32'>),
#  '0.6.1.bn2.running_mean': Parameter (shape=(128,), dtype=<class 'numpy.float32'>),
#  '0.6.1.bn2.running_var': Parameter (shape=(128,), dtype=<class 'numpy.float32'>),
#  '0.6.1.conv2.weight': Parameter (shape=(128, 128, 3, 3), dtype=<class 'numpy.float32'>),
#  '0.7.0.bn1.gamma': Parameter (shape=(128,), dtype=<class 'numpy.float32'>),
#  '0.7.0.bn1.beta': Parameter (shape=(128,), dtype=<class 'numpy.float32'>),
#  '0.7.0.bn1.running_mean': Parameter (shape=(128,), dtype=<class 'numpy.float32'>),
#  '0.7.0.bn1.running_var': Parameter (shape=(128,), dtype=<class 'numpy.float32'>),
#  '0.7.0.conv1.weight': Parameter (shape=(256, 128, 3, 3), dtype=<class 'numpy.float32'>),
#  '0.7.0.bn2.gamma': Parameter (shape=(256,), dtype=<class 'numpy.float32'>),
#  '0.7.0.bn2.beta': Parameter (shape=(256,), dtype=<class 'numpy.float32'>),
#  '0.7.0.bn2.running_mean': Parameter (shape=(256,), dtype=<class 'numpy.float32'>),
#  '0.7.0.bn2.running_var': Parameter (shape=(256,), dtype=<class 'numpy.float32'>),
#  '0.7.0.conv2.weight': Parameter (shape=(256, 256, 3, 3), dtype=<class 'numpy.float32'>),
#  '0.7.0.downsample.weight': Parameter (shape=(256, 128, 1, 1), dtype=<class 'numpy.float32'>),
#  '0.7.1.bn1.gamma': Parameter (shape=(256,), dtype=<class 'numpy.float32'>),
#  '0.7.1.bn1.beta': Parameter (shape=(256,), dtype=<class 'numpy.float32'>),
#  '0.7.1.bn1.running_mean': Parameter (shape=(256,), dtype=<class 'numpy.float32'>),
#  '0.7.1.bn1.running_var': Parameter (shape=(256,), dtype=<class 'numpy.float32'>),
#  '0.7.1.conv1.weight': Parameter (shape=(256, 256, 3, 3), dtype=<class 'numpy.float32'>),
#  '0.7.1.bn2.gamma': Parameter (shape=(256,), dtype=<class 'numpy.float32'>),
#  '0.7.1.bn2.beta': Parameter (shape=(256,), dtype=<class 'numpy.float32'>),
#  '0.7.1.bn2.running_mean': Parameter (shape=(256,), dtype=<class 'numpy.float32'>),
#  '0.7.1.bn2.running_var': Parameter (shape=(256,), dtype=<class 'numpy.float32'>),
#  '0.7.1.conv2.weight': Parameter (shape=(256, 256, 3, 3), dtype=<class 'numpy.float32'>),
#  '0.8.0.bn1.gamma': Parameter (shape=(256,), dtype=<class 'numpy.float32'>),
#  '0.8.0.bn1.beta': Parameter (shape=(256,), dtype=<class 'numpy.float32'>),
#  '0.8.0.bn1.running_mean': Parameter (shape=(256,), dtype=<class 'numpy.float32'>),
#  '0.8.0.bn1.running_var': Parameter (shape=(256,), dtype=<class 'numpy.float32'>),
#  '0.8.0.conv1.weight': Parameter (shape=(512, 256, 3, 3), dtype=<class 'numpy.float32'>),
#  '0.8.0.bn2.gamma': Parameter (shape=(512,), dtype=<class 'numpy.float32'>),
#  '0.8.0.bn2.beta': Parameter (shape=(512,), dtype=<class 'numpy.float32'>),
#  '0.8.0.bn2.running_mean': Parameter (shape=(512,), dtype=<class 'numpy.float32'>),
#  '0.8.0.bn2.running_var': Parameter (shape=(512,), dtype=<class 'numpy.float32'>),
#  '0.8.0.conv2.weight': Parameter (shape=(512, 512, 3, 3), dtype=<class 'numpy.float32'>),
#  '0.8.0.downsample.weight': Parameter (shape=(512, 256, 1, 1), dtype=<class 'numpy.float32'>),
#  '0.8.1.bn1.gamma': Parameter (shape=(512,), dtype=<class 'numpy.float32'>),
#  '0.8.1.bn1.beta': Parameter (shape=(512,), dtype=<class 'numpy.float32'>),
#  '0.8.1.bn1.running_mean': Parameter (shape=(512,), dtype=<class 'numpy.float32'>),
#  '0.8.1.bn1.running_var': Parameter (shape=(512,), dtype=<class 'numpy.float32'>),
#  '0.8.1.conv1.weight': Parameter (shape=(512, 512, 3, 3), dtype=<class 'numpy.float32'>),
#  '0.8.1.bn2.gamma': Parameter (shape=(512,), dtype=<class 'numpy.float32'>),
#  '0.8.1.bn2.beta': Parameter (shape=(512,), dtype=<class 'numpy.float32'>),
#  '0.8.1.bn2.running_mean': Parameter (shape=(512,), dtype=<class 'numpy.float32'>),
#  '0.8.1.bn2.running_var': Parameter (shape=(512,), dtype=<class 'numpy.float32'>),
#  '0.8.1.conv2.weight': Parameter (shape=(512, 512, 3, 3), dtype=<class 'numpy.float32'>),
#  '0.9.gamma': Parameter (shape=(512,), dtype=<class 'numpy.float32'>),
#  '0.9.beta': Parameter (shape=(512,), dtype=<class 'numpy.float32'>),
#  '0.9.running_mean': Parameter (shape=(512,), dtype=<class 'numpy.float32'>),
#  '0.9.running_var': Parameter (shape=(512,), dtype=<class 'numpy.float32'>),
#  '1.weight': Parameter (shape=(3, 512), dtype=float32),
#  '1.bias': Parameter (shape=(3,), dtype=float32)}
